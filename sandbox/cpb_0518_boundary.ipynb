# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#env" data-toc-modified-id="env-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>env</a></span></li><li><span><a href="#sensitivity-analysis" data-toc-modified-id="sensitivity-analysis-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>sensitivity analysis</a></span><ul class="toc-item"><li><span><a href="#$x$:-carbon-removal-rate-($t^{-1}$)" data-toc-modified-id="$x$:-carbon-removal-rate-($t^{-1}$)-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>$x$: carbon removal rate ($t^{-1}$)</a></span></li><li><span><a href="#$e_{PR}$:-fraction-of-non-respired-carbon-in-phytoplankton-(no-unit)" data-toc-modified-id="$e_{PR}$:-fraction-of-non-respired-carbon-in-phytoplankton-(no-unit)-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>$e_{PR}$: fraction of non-respired carbon in phytoplankton (no unit)</a></span></li><li><span><a href="#$e_P$:-fraction-of-carbon-incorporated-into-phytoplankton-biomass-(no-unit)" data-toc-modified-id="$e_P$:-fraction-of-carbon-incorporated-into-phytoplankton-biomass-(no-unit)-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>$e_P$: fraction of carbon incorporated into phytoplankton biomass (no unit)</a></span></li><li><span><a href="#$g_P$:-phytoplankton-growth-rate-($t^{-1}$)" data-toc-modified-id="$g_P$:-phytoplankton-growth-rate-($t^{-1}$)-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>$g_P$: phytoplankton growth rate ($t^{-1}$)</a></span></li><li><span><a href="#$a_P$:-phytoplankton-intraspecific-interference-rate-($\dfrac{m^3}{gC\cdot-t}$)" data-toc-modified-id="$a_P$:-phytoplankton-intraspecific-interference-rate-($\dfrac{m^3}{gC\cdot-t}$)-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>$a_P$: phytoplankton intraspecific interference rate ($\dfrac{m^3}{gC\cdot t}$)</a></span></li><li><span><a href="#$e_{BR}$:-fraction-of-non-respired-carbon-in-bacterial-decomposer-(no-unit)" data-toc-modified-id="$e_{BR}$:-fraction-of-non-respired-carbon-in-bacterial-decomposer-(no-unit)-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>$e_{BR}$: fraction of non-respired carbon in bacterial decomposer (no unit)</a></span></li><li><span><a href="#$e_B$:-fraction-of-carbon-incorporated-into-bacterial-decomposer-biomass-(no-unit)" data-toc-modified-id="$e_B$:-fraction-of-carbon-incorporated-into-bacterial-decomposer-biomass-(no-unit)-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>$e_B$: fraction of carbon incorporated into bacterial decomposer biomass (no unit)</a></span></li><li><span><a href="#$g_B$:-bacterial-decomposer-growth-rate-per-density-($\dfrac{m^3}{gC\cdot-t}$)" data-toc-modified-id="$g_B$:-bacterial-decomposer-growth-rate-per-density-($\dfrac{m^3}{gC\cdot-t}$)-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>$g_B$: bacterial decomposer growth rate per density ($\dfrac{m^3}{gC\cdot t}$)</a></span></li><li><span><a href="#$m_B$:-bacterial-decomposer-death-rate-($t^{-1}$)" data-toc-modified-id="$m_B$:-bacterial-decomposer-death-rate-($t^{-1}$)-2.9"><span class="toc-item-num">2.9&nbsp;&nbsp;</span>$m_B$: bacterial decomposer death rate ($t^{-1}$)</a></span></li></ul></li><li><span><a href="#boundary-initial-population" data-toc-modified-id="boundary-initial-population-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>boundary initial population</a></span><ul class="toc-item"><li><span><a href="#categoty-4444440" data-toc-modified-id="categoty-4444440-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>categoty 4444440</a></span></li><li><span><a href="#category-4444404" data-toc-modified-id="category-4444404-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>category 4444404</a></span></li><li><span><a href="#category-4444400" data-toc-modified-id="category-4444400-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>category 4444400</a></span></li><li><span><a href="#category-4444433" data-toc-modified-id="category-4444433-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>category 4444433</a></span></li><li><span><a href="#category-4444333" data-toc-modified-id="category-4444333-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>category 4444333</a></span></li><li><span><a href="#category-4444443" data-toc-modified-id="category-4444443-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>category 4444443</a></span></li><li><span><a href="#category-4333333" data-toc-modified-id="category-4333333-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>category 4333333</a></span></li><li><span><a href="#category-4433333" data-toc-modified-id="category-4433333-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>category 4433333</a></span></li><li><span><a href="#category-4443333" data-toc-modified-id="category-4443333-3.9"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>category 4443333</a></span></li></ul></li></ul></div>

# %% [markdown]
# # env

# %%
library(repr) ; options(repr.plot.width=18, repr.plot.height= 10) ## change plot default parameter in Jupyter
source("../code/func.R")

# %%
cAt = read.csv("p_tmp/eqmSummary.csv", header = T)
cAtid = unique(cAt$eqmid);cAtid
# Out:
#  [1] 4444444 4444440 4444404 4444400 4444433 4444333 4444443 4333333 4433333
# [10] 3333333 4443333

# %% [markdown]
# # sensitivity analysis

# %%
dEfIni = rep(1e-5,3)
dEfpAr = c(.5,.875,.63,.3,.2,.6,.55,5,.14)
dEfpAN = c("x","e_PR","e_P","g_P","a_P","e_BR","e_B","g_B","m_B")
ebcAlt(dEfpAr)
# Out:
#   C          P        B         total
# 1 0.00000000 0.000000  0.000000  0.0000000
# 2 0.08484848 0.000000 -0.250000 -0.1651515
# 3 0.43410938 0.826875  0.000000  1.2609844
# 4 0.08484848 0.826875  1.029072  1.9407958

# %%
pApLt = function(pA, rAg=c(0,5), eT=100, iniPop=dEfIni, name=dEfpAN, values=dEfpAr){
    a0 = as.data.frame(matrix(NA,nc=5,nr=eT))
    sEq=seq(rAg[1],rAg[2],(rAg[2]-rAg[1])/eT)
    for(i in 1:eT){
        tpAr = values
        tpAr[pA] = sEq[i]
        a = ebcData(iniPop = iniPop, parameter = tpAr)
        a0[i,] = c(sEq[i],a[nrow(a),-1])
    };rm(i)
    colnames(a0) = c(name[pA],"C","P","B","A")

    matplot(a0[,1],a0[,-1], type="l", lty=1, lwd=5, col=cBp[-c(3,5)], xlab=colnames(a0)[1], ylab="carbon density (gC/m^3)", cex.lab=2, cex.axis=2, cex.main=2, main=paste0(name[-pA]," = ",tpAr[-pA], collapse=", "))
    legend("topleft", inset=c(0,0), legend = paste0(colnames(a0)[-1],": ",round(a0[nrow(a0),-1],2)), pch = rep(16,3), col = cBp[-c(3,5)], bty="n", cex = 2)
}

# %% [markdown]
# ## $x$: carbon removal rate ($t^{-1}$)

# %%
pApLt(1,c(0,5))
# Out:
# Plot with title “e_PR = 0.875, e_P = 0.63, g_P = 0.3, a_P = 0.2, e_BR = 0.6, e_B = 0.55, g_B = 5, m_B = 0.14”

# %% [markdown]
# ## $e_{PR}$: fraction of non-respired carbon in phytoplankton (no unit)

# %%
pApLt(2,c(.6,.9))
# Out:
# Plot with title “x = 0.5, e_P = 0.63, g_P = 0.3, a_P = 0.2, e_BR = 0.6, e_B = 0.55, g_B = 5, m_B = 0.14”

# %% [markdown]
# ## $e_P$: fraction of carbon incorporated into phytoplankton biomass (no unit)

# %%
pApLt(3,c(.4,.7))
# Out:
# Plot with title “x = 0.5, e_PR = 0.875, g_P = 0.3, a_P = 0.2, e_BR = 0.6, e_B = 0.55, g_B = 5, m_B = 0.14”

# %% [markdown]
# ## $g_P$: phytoplankton growth rate ($t^{-1}$)

# %%
pApLt(4,c(.2,.4))
# Out:
# Plot with title “x = 0.5, e_PR = 0.875, e_P = 0.63, a_P = 0.2, e_BR = 0.6, e_B = 0.55, g_B = 5, m_B = 0.14”

# %% [markdown]
# ## $a_P$: phytoplankton intraspecific interference rate ($\dfrac{m^3}{gC\cdot t}$)

# %%
pApLt(5,c(.1,.4))
# Out:
# Plot with title “x = 0.5, e_PR = 0.875, e_P = 0.63, g_P = 0.3, e_BR = 0.6, e_B = 0.55, g_B = 5, m_B = 0.14”

# %% [markdown]
# ## $e_{BR}$: fraction of non-respired carbon in bacterial decomposer (no unit)

# %%
pApLt(6,c(.5,.7))
# Out:
# Plot with title “x = 0.5, e_PR = 0.875, e_P = 0.63, g_P = 0.3, a_P = 0.2, e_B = 0.55, g_B = 5, m_B = 0.14”

# %% [markdown]
# ## $e_B$: fraction of carbon incorporated into bacterial decomposer biomass (no unit)

# %%
pApLt(7,c(.5,.7))
# Out:
# Plot with title “x = 0.5, e_PR = 0.875, e_P = 0.63, g_P = 0.3, a_P = 0.2, e_BR = 0.6, g_B = 5, m_B = 0.14”

# %% [markdown]
# ## $g_B$: bacterial decomposer growth rate per density ($\dfrac{m^3}{gC\cdot t}$)

# %%
pApLt(8,c(1,8))
# Out:
# Plot with title “x = 0.5, e_PR = 0.875, e_P = 0.63, g_P = 0.3, a_P = 0.2, e_BR = 0.6, e_B = 0.55, m_B = 0.14”

# %% [markdown]
# ## $m_B$: bacterial decomposer death rate ($t^{-1}$)

# %%
pApLt(9,c(.1,.2))
# Out:
# Plot with title “x = 0.5, e_PR = 0.875, e_P = 0.63, g_P = 0.3, a_P = 0.2, e_BR = 0.6, e_B = 0.55, g_B = 5”

# %% [markdown]
# # boundary initial population

# %%
for(i in 1:length(cAtid)){if(i!=1 & i!=10){
    assign(paste0("cAt",cAtid[i]),cAt[which(cAt$eqmid==cAtid[i]),8:16])
}};rm(i)

# %%
bOndary = function(df, row){
    pA = as.numeric(df[row,])
    name = colnames(df[row,])
    
    a1 = ebcAlt(pA,2)
    a1 = a1[which(a1!=Inf)]

    a = as.data.frame(matrix(NA,nc=5,nr=13))
    for(i in 1:13){
        a0 = ebcData(iniPop=10^-(i-1),parameter = pA)
        a[i,] = c(-(i-1), a0[nrow(a0),-1])
    };rm(i)
    colnames(a) = c("log10(iniPop)","C","P","B","A")

    rAngePlt = c(0,max(a1)*1.1)
    matplot(a[,1],a[,-1], type="l", lty=1, lwd=5, col=cBp[-c(3,5)], xlab=colnames(a)[1], ylab="final carbon density (gC/m^3)", cex.lab=2, cex.axis=2, cex.main=2, main=paste0(name," = ",pA, collapse=", "), ylim=rAngePlt)
    legend("topright", inset=c(.3,0), legend = colnames(a)[-1], pch = rep(16,3), col = cBp[-c(3,5)], bty="n", cex = 2) # legend = paste0(colnames(a)[-1],": ",signif(a[nrow(a),-1],2))
    
    yL = a[nrow(a),-1]
    for(i in 1:length(yL)){if(yL[i]>rAngePlt[2] | yL[i]<0){yL[i] = rAngePlt[2]/5*i}};rm(i)
    text(x=rep(a[nrow(a),1],4), y=yL+rAngePlt[2]*.05, label=paste0(colnames(a)[-1],": ",signif(a[nrow(a),-1],4)), cex=1.3)
    
    yR = a[1,-1]
    for(i in 1:length(yR)){if(yR[i]>rAngePlt[2] | yR[i]<0){yR[i] = rAngePlt[2]/5*i}};rm(i)
    text(x=rep(a[1,1],4), y=yR+rAngePlt[2]*.05, label=paste0(colnames(a)[-1],": ",signif(a[1,-1],4)), cex=1.3)
}

# %% [markdown]
# ## categoty 4444440

# %%
dim(cAt4444440)
# Out:
# [1] 24075     9

# %%
cAt4444440[1,]
# Out:
#    x e_PR  e_P  g_P   a_P   e_BR e_B  g_B   m_B
# 21 0 0.875 0.63 0.259 0.001 0.6  0.55 2.367 0.14

# %%
bOndary(cAt4444440,1)
# Out:
# DLSODA-  Warning..Internal T (=R1) and H (=R2) are
#       such that in the machine, T + H = T on the next step
#      (H = step size). Solver will continue anyway.
# In above message, R1 = 208.31, R2 = 1.39552e-14
#
# DLSODA-  Warning..Internal T (=R1) and H (=R2) are
#       such that in the machine, T + H = T on the next step
#      (H = step size). Solver will continue anyway.
# In above message, R1 = 208.31, R2 = 1.39552e-14
#
# DLSODA-  Warning..Internal T (=R1) and H (=R2) are
#       such that in the machine, T + H = T on the next step
#      (H = step size). Solver will continue anyway.
# In above message, R1 = 208.31, R2 = 1.39552e-14
#
# DLSODA-  Warning..Internal T (=R1) and H (=R2) are
#       such that in the machine, T + H = T on the next step
#      (H = step size). Solver will continue anyway.
# In above message, R1 = 208.31, R2 = 1.39552e-14
#
# DLSODA-  Warning..Internal T (=R1) and H (=R2) are
#       such that in the machine, T + H = T on the next step
# ...

# %% [markdown]
# ## category 4444404

# %%
dim(cAt4444404)
# Out:
# [1] 15975     9

# %%
cAt4444404[1,]
# Out:
#    x e_PR  e_P  g_P   a_P   e_BR e_B  g_B m_B
# 78 0 0.875 0.63 0.259 0.001 0.6  0.55 7.1 0.14

# %%
bOndary(cAt4444404,1)
# Out:
# DLSODA-  Warning..Internal T (=R1) and H (=R2) are
#       such that in the machine, T + H = T on the next step
#      (H = step size). Solver will continue anyway.
# In above message, R1 = 184.703, R2 = 1.39477e-14
#
# DLSODA-  Warning..Internal T (=R1) and H (=R2) are
#       such that in the machine, T + H = T on the next step
#      (H = step size). Solver will continue anyway.
# In above message, R1 = 184.703, R2 = 1.39477e-14
#
# DLSODA-  Warning..Internal T (=R1) and H (=R2) are
#       such that in the machine, T + H = T on the next step
#      (H = step size). Solver will continue anyway.
# In above message, R1 = 184.703, R2 = 1.39477e-14
#
# DLSODA-  Warning..Internal T (=R1) and H (=R2) are
#       such that in the machine, T + H = T on the next step
#      (H = step size). Solver will continue anyway.
# In above message, R1 = 184.703, R2 = 1.39477e-14
#
# DLSODA-  Warning..Internal T (=R1) and H (=R2) are
#       such that in the machine, T + H = T on the next step
# ...

# %% [markdown]
# ## category 4444400

# %%
dim(cAt4444400)
# Out:
# [1] 9562    9

# %%
cAt4444400[1,]
# Out:
#     x e_PR  e_P  g_P   a_P    e_BR e_B  g_B   m_B
# 112 0 0.875 0.63 0.259 0.0409 0.6  0.55 1.537 0.14

# %%
bOndary(cAt4444400,1)
# Out:
# DLSODA-  Warning..Internal T (=R1) and H (=R2) are
#       such that in the machine, T + H = T on the next step
#      (H = step size). Solver will continue anyway.
# In above message, R1 = 198.969, R2 = 1.17095e-14
#
# DLSODA-  Warning..Internal T (=R1) and H (=R2) are
#       such that in the machine, T + H = T on the next step
#      (H = step size). Solver will continue anyway.
# In above message, R1 = 198.969, R2 = 1.17095e-14
#
# DLSODA-  Warning..Internal T (=R1) and H (=R2) are
#       such that in the machine, T + H = T on the next step
#      (H = step size). Solver will continue anyway.
# In above message, R1 = 198.969, R2 = 1.17095e-14
#
# DLSODA-  Warning..Internal T (=R1) and H (=R2) are
#       such that in the machine, T + H = T on the next step
#      (H = step size). Solver will continue anyway.
# In above message, R1 = 198.969, R2 = 1.17095e-14
#
# DLSODA-  Warning..Internal T (=R1) and H (=R2) are
#       such that in the machine, T + H = T on the next step
# ...

# %% [markdown]
# ## category 4444433

# %%
dim(cAt4444433)
# Out:
# [1] 15871     9

# %%
cAt4444433[1,]
# Out:
#        x   e_PR  e_P  g_P   a_P e_BR e_B  g_B   m_B
# 123221 0.1 0.875 0.63 0.259 0.4 0.6  0.55 0.707 0.14

# %%
bOndary(cAt4444433,1)
# Out:
# Plot with title “x = 0.1, e_PR = 0.875, e_P = 0.63, g_P = 0.259, a_P = 0.4, e_BR = 0.6, e_B = 0.55, g_B = 0.707, m_B = 0.14”

# %% [markdown]
# ## category 4444333

# %%
dim(cAt4444333)
# Out:
# [1] 2535    9

# %%
cAt4444333[1,]
# Out:
#        x    e_PR  e_P  g_P   a_P e_BR e_B  g_B   m_B
# 147663 0.12 0.875 0.63 0.259 0.4 0.6  0.55 0.707 0.14

# %%
bOndary(cAt4444333,1)
# Out:
# Plot with title “x = 0.12, e_PR = 0.875, e_P = 0.63, g_P = 0.259, a_P = 0.4, e_BR = 0.6, e_B = 0.55, g_B = 0.707, m_B = 0.14”

# %% [markdown]
# ## category 4444443

# %%
dim(cAt4444443)
# Out:
# [1] 2817    9

# %%
cAt4444443[1,]
# Out:
#        x    e_PR  e_P  g_P    a_P e_BR e_B  g_B   m_B
# 148774 0.12 0.875 0.63 0.2888 0.4 0.6  0.55 0.707 0.14

# %%
bOndary(cAt4444443,1)
# Out:
# Plot with title “x = 0.12, e_PR = 0.875, e_P = 0.63, g_P = 0.2888, a_P = 0.4, e_BR = 0.6, e_B = 0.55, g_B = 0.707, m_B = 0.14”

# %% [markdown]
# ## category 4333333

# %%
dim(cAt4333333)
# Out:
# [1] 2734    9

# %%
cAt4333333[1,]
# Out:
#        x    e_PR  e_P  g_P   a_P e_BR e_B  g_B   m_B
# 159884 0.13 0.875 0.63 0.259 0.4 0.6  0.55 0.707 0.14

# %%
bOndary(cAt4333333,1)
# Out:
# Plot with title “x = 0.13, e_PR = 0.875, e_P = 0.63, g_P = 0.259, a_P = 0.4, e_BR = 0.6, e_B = 0.55, g_B = 0.707, m_B = 0.14”

# %% [markdown]
# ## category 4433333

# %%
dim(cAt4433333)
# Out:
# [1] 2611    9

# %%
cAt4433333[1,]
# Out:
#        x    e_PR  e_P  g_P   a_P  e_BR e_B  g_B   m_B
# 172004 0.14 0.875 0.63 0.259 0.36 0.6  0.55 0.707 0.14

# %%
bOndary(cAt4433333,1)
# Out:
# Plot with title “x = 0.14, e_PR = 0.875, e_P = 0.63, g_P = 0.259, a_P = 0.36, e_BR = 0.6, e_B = 0.55, g_B = 0.707, m_B = 0.14”

# %% [markdown]
# ## category 4443333

# %%
dim(cAt4443333)
# Out:
# [1] 2517    9

# %%
cAt4443333[1,]
# Out:
#        x    e_PR  e_P  g_P   a_P    e_BR e_B  g_B   m_B
# 184124 0.15 0.875 0.63 0.259 0.3203 0.6  0.55 0.707 0.14

# %%
bOndary(cAt4443333,1)
# Out:
# Plot with title “x = 0.15, e_PR = 0.875, e_P = 0.63, g_P = 0.259, a_P = 0.3203, e_BR = 0.6, e_B = 0.55, g_B = 0.707, m_B = 0.14”
